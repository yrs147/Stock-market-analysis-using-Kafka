# %%
pip install s3fs
# Out:
# Collecting s3fs
#   Downloading s3fs-2023.6.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\yash raj\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from s3fs) (3.8.4)
# Collecting fsspec==2023.6.0
#   Downloading fsspec-2023.6.0-py3-none-any.whl (163 kB)
#      ---------------------------------------- 0.0/163.8 kB ? eta -:--:--
#      -------------------------------------- 163.8/163.8 kB 9.6 MB/s eta 0:00:00
# Collecting aiobotocore~=2.5.0
#   Downloading aiobotocore-2.5.1-py3-none-any.whl (72 kB)
#      ---------------------------------------- 0.0/72.8 kB ? eta -:--:--
#      ---------------------------------------- 72.8/72.8 kB 3.9 MB/s eta 0:00:00
# Collecting wrapt<2.0.0,>=1.10.10
#   Downloading wrapt-1.15.0-cp310-cp310-win_amd64.whl (36 kB)
# Collecting aioitertools<1.0.0,>=0.5.1
#   Downloading aioitertools-0.11.0-py3-none-any.whl (23 kB)
# Collecting botocore<1.29.162,>=1.29.161
#   Downloading botocore-1.29.161-py3-none-any.whl (10.9 MB)
#      ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#      ------ --------------------------------- 1.9/10.9 MB 60.4 MB/s eta 0:00:01
#      -------------- ------------------------- 4.0/10.9 MB 50.8 MB/s eta 0:00:01
#      ------------------- -------------------- 5.3/10.9 MB 41.9 MB/s eta 0:00:01
#      --------------------- ------------------ 5.9/10.9 MB 34.1 MB/s eta 0:00:01
#      ----------------------- ---------------- 6.5/10.9 MB 29.8 MB/s eta 0:00:01
#      -------------------------- ------------- 7.2/10.9 MB 27.0 MB/s eta 0:00:01
#      ---------------------------- ----------- 7.8/10.9 MB 24.9 MB/s eta 0:00:01
#      ------------------------------ --------- 8.4/10.9 MB 23.5 MB/s eta 0:00:01
#      --------------------------------- ------ 9.2/10.9 MB 22.7 MB/s eta 0:00:01
#      ----------------------------------- --- 10.0/10.9 MB 22.0 MB/s eta 0:00:01
#      --------------------------------------  10.8/10.9 MB 21.1 MB/s eta 0:00:01
#      --------------------------------------- 10.9/10.9 MB 19.2 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\yash raj\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\yash raj\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\yash raj\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.8.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\yash raj\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\yash raj\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (23.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\yash raj\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\yash raj\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.3.3)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\yash raj\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from botocore<1.29.162,>=1.29.161->aiobotocore~=2.5.0->s3fs) (1.26.15)
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\yash raj\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from botocore<1.29.162,>=1.29.161->aiobotocore~=2.5.0->s3fs) (2.8.2)
# Requirement already satisfied: idna>=2.0 in c:\users\yash raj\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.4)
# Requirement already satisfied: six>=1.5 in c:\users\yash raj\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.29.162,>=1.29.161->aiobotocore~=2.5.0->s3fs) (1.16.0)
# Installing collected packages: wrapt, jmespath, fsspec, aioitertools, botocore, aiobotocore, s3fs
# Successfully installed aiobotocore-2.5.1 aioitertools-0.11.0 botocore-1.29.161 fsspec-2023.6.0 jmespath-1.0.1 s3fs-2023.6.0 wrapt-1.15.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\Yash Raj\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from kafka import KafkaConsumer
from time import sleep
from json import dumps,loads
import json
from s3fs import S3FileSystem

# %%
consumer = KafkaConsumer(
    'demo_test',
     bootstrap_servers=[':9092'], #add your IP here
    value_deserializer=lambda x: loads(x.decode('utf-8')))

# %%
for c in consumer:
    print(c.value)
# Out:
# {'Index': 'N100', 'Date': '2018-03-14', 'Open': 1022.780029, 'High': 1028.560059, 'Low': 1019.119995, 'Close': 1020.950012, 'Adj Close': 1020.950012, 'Volume': 180879100.0, 'CloseUSD': 1245.55901464}
# {'Index': 'IXIC', 'Date': '1994-04-20', 'Open': 716.320007, 'High': 717.719971, 'Low': 703.400024, 'Close': 705.52002, 'Adj Close': 705.52002, 'Volume': 335340000.0, 'CloseUSD': 705.52002}
# {'Index': 'IXIC', 'Date': '2012-09-10', 'Open': 3131.340088, 'High': 3133.889893, 'Low': 3102.76001, 'Close': 3104.02002, 'Adj Close': 3104.02002, 'Volume': 1575370000.0, 'CloseUSD': 3104.02002}
# {'Index': 'IXIC', 'Date': '1988-05-24', 'Open': 363.799988, 'High': 365.200012, 'Low': 363.299988, 'Close': 365.200012, 'Adj Close': 365.200012, 'Volume': 109730000.0, 'CloseUSD': 365.200012}
# {'Index': 'IXIC', 'Date': '1983-12-30', 'Open': 278.600006, 'High': 278.600006, 'Low': 278.600006, 'Close': 278.600006, 'Adj Close': 278.600006, 'Volume': 0.0, 'CloseUSD': 278.600006}
# {'Index': 'N225', 'Date': '1999-02-12', 'Open': 13925.24023, 'High': 14062.91992, 'Low': 13925.24023, 'Close': 13973.69043, 'Adj Close': 13973.69043, 'Volume': 0.0, 'CloseUSD': 139.73690430000002}
# {'Index': 'IXIC', 'Date': '1999-09-14', 'Open': 2843.530029, 'High': 2870.26001, 'Low': 2837.929932, 'Close': 2868.290039, 'Adj Close': 2868.290039, 'Volume': 1013000000.0, 'CloseUSD': 2868.290039}
# {'Index': 'NYA', 'Date': '2020-05-13', 'Open': 11035.23047, 'High': 11038.37988, 'Low': 10747.80957, 'Close': 10829.44043, 'Adj Close': 10829.44043, 'Volume': 6143130000.0, 'CloseUSD': 10829.44043}
# {'Index': 'GSPTSE', 'Date': '1985-01-15', 'Open': 2399.800049, 'High': 2404.399902, 'Low': 2393.399902, 'Close': 2394.100098, 'Adj Close': 2388.020264, 'Volume': 10490000.0, 'CloseUSD': 1987.10308134}
# {'Index': 'HSI', 'Date': '2003-01-24', 'Open': 9558.480469, 'High': 9575.269531, 'Low': 9416.120117, 'Close': 9460.599609, 'Adj Close': 9460.599609, 'Volume': 220192000.0, 'CloseUSD': 1229.8779491700002}
# {'Index': 'GSPTSE', 'Date': '2018-12-28', 'Open': 14234.2002, 'High': 14326.90039, 'Low': 14174.0, 'Close': 14222.0, 'Adj Close': 14222.0, 'Volume': 26692860000.0, 'CloseUSD': 11804.26}
# {'Index': 'SSMI', 'Date': '2012-03-05', 'Open': 6143.040039, 'High': 6169.029785, 'Low': 6120.259766, 'Close': 6153.910156, 'Adj Close': 6153.910156, 'Volume': 36025100.0, 'CloseUSD': 6830.840273160001}
# {'Index': 'N225', 'Date': '1971-04-07', 'Open': 2416.919922, 'High': 2416.919922, 'Low': 2416.919922, 'Close': 2416.919922, 'Adj Close': 2416.919922, 'Volume': 0.0, 'CloseUSD': 24.16919922}
# {'Index': 'TWII', 'Date': '1999-09-16', 'Open': 7897.560059, 'High': 8003.399902, 'Low': 7897.560059, 'Close': 7968.899902, 'Adj Close': 7968.869629, 'Volume': 0.0, 'CloseUSD': 318.75599608}
# {'Index': 'N100', 'Date': '2005-11-10', 'Open': 768.169983, 'High': 770.320007, 'Low': 765.76001, 'Close': 766.75, 'Adj Close': 766.75, 'Volume': 0.0, 'CloseUSD': 935.435}
# {'Index': 'IXIC', 'Date': '2014-03-25', 'Open': 4252.649902, 'High': 4274.319824, 'Low': 4203.640137, 'Close': 4234.27002, 'Adj Close': 4234.27002, 'Volume': 2270760000.0, 'CloseUSD': 4234.27002}
# {'Index': '000001.SS', 'Date': '2020-06-22', 'Open': 2966.900879, 'High': 2983.437988, 'Low': 2959.034912, 'Close': 2965.271973, 'Adj Close': 2965.271973, 'Volume': 267900.0, 'CloseUSD': 474.44351568}
# {'Index': 'SSMI', 'Date': '1999-10-11', 'Open': 7110.100098, 'High': 7133.0, 'Low': 7087.299805, 'Close': 7110.0, 'Adj Close': 7110.0, 'Volume': 0.0, 'CloseUSD': 7892.1}
# {'Index': 'N225', 'Date': '1979-10-30', 'Open': 6405.580078, 'High': 6405.580078, 'Low': 6405.580078, 'Close': 6405.580078, 'Adj Close': 6405.580078, 'Volume': 0.0, 'CloseUSD': 64.05580078}
# {'Index': 'NYA', 'Date': '2012-10-24', 'Open': 8219.889648, 'High': 8237.410156, 'Low': 8169.080078, 'Close': 8179.259766, 'Adj Close': 8179.259766, 'Volume': 3385970000.0, 'CloseUSD': 8179.259766}
# {'Index': 'NYA', 'Date': '2014-07-30', 'Open': 10957.98047, 'High': 10974.17969, 'Low': 10887.08984, 'Close': 10929.79004, 'Adj Close': 10929.79004, 'Volume': 3448250000.0, 'CloseUSD': 10929.79004}
# {'Index': 'N100', 'Date': '2013-04-03', 'Open': 722.869995, 'High': 726.429993, 'Low': 716.900024, 'Close': 717.23999, 'Adj Close': 717.23999, 'Volume': 226350000.0, 'CloseUSD': 875.0327878}
# {'Index': '399001.SZ', 'Date': '2012-04-12', 'Open': 9817.780273, 'High': 10013.2002, 'Low': 9779.679688, 'Close': 10007.65039, 'Adj Close': 10007.53809, 'Volume': 87100.0, 'CloseUSD': 1601.2240624}
# {'Index': 'N225', 'Date': '2004-05-20', 'Open': 10949.07031, 'High': 11045.66016, 'Low': 10760.69043, 'Close': 10862.04004, 'Adj Close': 10862.04004, 'Volume': 98000000.0, 'CloseUSD': 108.6204004}
# {'Index': '000001.SS', 'Date': '2017-09-20', 'Open': 3352.185059, 'High': 3370.0979, 'Low': 3346.535889, 'Close': 3365.996094, 'Adj Close': 3365.996094, 'Volume': 192200.0, 'CloseUSD': 538.5593750400001}
# {'Index': 'N100', 'Date': '2011-08-16', 'Open': 596.400024, 'High': 596.400024, 'Low': 596.400024, 'Close': 596.400024, 'Adj Close': 596.400024, 'Volume': 264522800.0, 'CloseUSD': 727.60802928}
# {'Index': 'N225', 'Date': '1976-10-28', 'Open': 4641.029785, 'High': 4641.029785, 'Low': 4641.029785, 'Close': 4641.029785, 'Adj Close': 4641.029785, 'Volume': 0.0, 'CloseUSD': 46.41029785}
# {'Index': 'NYA', 'Date': '1988-04-14', 'Open': 1555.819946, 'High': 1555.819946, 'Low': 1555.819946, 'Close': 1555.819946, 'Adj Close': 1555.819946, 'Volume': 0.0, 'CloseUSD': 1555.819946}
# {'Index': '399001.SZ', 'Date': '2003-09-01', 'Open': 3194.26001, 'High': 3250.110107, 'Low': 3183.810059, 'Close': 3249.189941, 'Adj Close': 3249.153564, 'Volume': 0.0, 'CloseUSD': 519.87039056}
# {'Index': 'N225', 'Date': '1966-10-26', 'Open': 1412.199951, 'High': 1412.199951, 'Low': 1412.199951, 'Close': 1412.199951, 'Adj Close': 1412.199951, 'Volume': 0.0, 'CloseUSD': 14.12199951}
# {'Index': 'GSPTSE', 'Date': '1984-03-19', 'Open': 2411.399902, 'High': 2413.199951, 'Low': 2407.100098, 'Close': 2412.600098, 'Adj Close': 2406.473389, 'Volume': 0.0, 'CloseUSD': 2002.45808134}
# {'Index': 'NYA', 'Date': '2001-12-12', 'Open': 6084.02002, 'High': 6084.02002, 'Low': 6084.02002, 'Close': 6084.02002, 'Adj Close': 6084.02002, 'Volume': 1449700000.0, 'CloseUSD': 6084.02002}
# {'Index': '399001.SZ', 'Date': '2002-06-14', 'Open': 3041.050049, 'High': 3041.070068, 'Low': 3018.860107, 'Close': 3023.209961, 'Adj Close': 3023.176025, 'Volume': 0.0, 'CloseUSD': 483.71359376}
# {'Index': 'SSMI', 'Date': '1996-05-13', 'Open': 3558.5, 'High': 3573.899902, 'Low': 3550.899902, 'Close': 3557.800049, 'Adj Close': 3557.800049, 'Volume': 0.0, 'CloseUSD': 3949.15805439}
# {'Index': 'N225', 'Date': '2020-03-06', 'Open': 21009.80078, 'High': 21061.19922, 'Low': 20613.91016, 'Close': 20749.75, 'Adj Close': 20749.75, 'Volume': 111700000.0, 'CloseUSD': 207.4975}
# {'Index': 'HSI', 'Date': '2018-05-15', 'Open': 31573.17969, 'High': 31573.17969, 'Low': 31152.0293, 'Close': 31152.0293, 'Adj Close': 31152.0293, 'Volume': 1566899600.0, 'CloseUSD': 4049.763809}
# {'Index': 'SSMI', 'Date': '2015-09-23', 'Open': 8492.900391, 'High': 8546.320313, 'Low': 8447.679688, 'Close': 8447.679688, 'Adj Close': 8447.679688, 'Volume': 48651000.0, 'CloseUSD': 9376.924453680002}
# {'Index': '399001.SZ', 'Date': '2005-08-31', 'Open': 2908.679932, 'High': 2950.560059, 'Low': 2902.340088, 'Close': 2950.429932, 'Adj Close': 2950.396729, 'Volume': 23100.0, 'CloseUSD': 472.06878912}
# {'Index': 'N225', 'Date': '2015-02-17', 'Open': 17949.69922, 'High': 18009.44922, 'Low': 17901.25977, 'Close': 17987.08984, 'Adj Close': 17987.08984, 'Volume': 142100000.0, 'CloseUSD': 179.87089840000002}
# {'Index': 'N100', 'Date': '2013-01-15', 'Open': 689.780029, 'High': 693.280029, 'Low': 689.26001, 'Close': 691.859985, 'Adj Close': 691.859985, 'Volume': 217028800.0, 'CloseUSD': 844.0691817000001}
# {'Index': 'SSMI', 'Date': '2002-06-14', 'Open': 6007.200195, 'High': 6011.799805, 'Low': 5862.200195, 'Close': 5980.700195, 'Adj Close': 5980.700195, 'Volume': 0.0, 'CloseUSD': 6638.577216450001}
# {'Index': 'N100', 'Date': '2014-08-01', 'Open': 814.210022, 'High': 814.25, 'Low': 800.869995, 'Close': 804.359985, 'Adj Close': 804.359985, 'Volume': 613117300.0, 'CloseUSD': 981.3191817}
# {'Index': '000001.SS', 'Date': '2015-11-03', 'Open': 3330.315918, 'High': 3346.274902, 'Low': 3302.184082, 'Close': 3316.695068, 'Adj Close': 3316.695068, 'Volume': 192900.0, 'CloseUSD': 530.67121088}
# {'Index': 'SSMI', 'Date': '2002-04-02', 'Open': 6651.600098, 'High': 6673.700195, 'Low': 6640.299805, 'Close': 6671.5, 'Adj Close': 6671.5, 'Volume': 0.0, 'CloseUSD': 7405.365000000001}
# {'Index': 'IXIC', 'Date': '2006-11-17', 'Open': 2439.629883, 'High': 2445.860107, 'Low': 2431.790039, 'Close': 2445.860107, 'Adj Close': 2445.860107, 'Volume': 1732400000.0, 'CloseUSD': 2445.860107}
# {'Index': 'GSPTSE', 'Date': '2011-08-18', 'Open': 12389.0, 'High': 12545.09961, 'Low': 12122.40039, 'Close': 12186.7002, 'Adj Close': 12186.7002, 'Volume': 23755960000.0, 'CloseUSD': 10114.961166}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 for c in consumer:
#       2     print(c.value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\kafka\consumer\group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\kafka\consumer\group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\kafka\consumer\group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\kafka\consumer\group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\kafka\consumer\group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\kafka\client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\kafka\client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\selectors.py:324, in SelectSelector.select(self, timeout)
#     322 ready = []
#     323 try:
# --> 324     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     325 except InterruptedError:
#     326     return ready
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\selectors.py:315, in SelectSelector._select(self, r, w, _, timeout)
#     314 def _select(self, r, w, _, timeout=None):
# --> 315     r, w, x = select.select(r, w, w, timeout)
#     316     return r, w + x, []
#
# KeyboardInterrupt:

# %%
s3 = S3FileSystem()

# %%
for count, i in enumerate(consumer):
    with s3.open("s3://kafka-stock-market/stock_market_{}.json".format(count), 'w') as file:
        json.dump(i.value, file)
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# Cell In[10], line 2
#       1 for count, i in enumerate(consumer):
# ----> 2     with s3.open("s3://kafka-stock-market/stock_market_{}.json".format(count), 'w') as file:
#       3         json.dump(i.value, file)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\fsspec\spec.py:1876, in AbstractBufferedFile.close(self)
#    1874 else:
#    1875     if not self.forced:
# -> 1876         self.flush(force=True)
#    1878     if self.fs is not None:
#    1879         self.fs.invalidate_cache(self.path)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\fsspec\spec.py:1747, in AbstractBufferedFile.flush(self, force)
#    1744         self.closed = True
#    1745         raise
# -> 1747 if self._upload_chunk(final=force) is not False:
#    1748     self.offset += self.buffer.seek(0, 2)
#    1749     self.buffer = io.BytesIO()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\s3fs\core.py:2250, in S3File._upload_chunk(self, final)
#    2247     self.parts.append({"PartNumber": part, "ETag": out["ETag"]})
#    2249 if self.autocommit and final:
# -> 2250     self.commit()
#    2251 return not final
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\s3fs\core.py:2265, in S3File.commit(self)
#    2263     self.buffer.seek(0)
#    2264     data = self.buffer.read()
# -> 2265     write_result = self._call_s3(
#    2266         "put_object",
#    2267         Key=self.key,
#    2268         Bucket=self.bucket,
#    2269         Body=data,
#    2270         ACL=self.acl,
#    2271         **self.kwargs,
#    2272     )
#    2273 else:
#    2274     raise RuntimeError
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\s3fs\core.py:2117, in S3File._call_s3(self, method, *kwarglist, **kwargs)
#    2116 def _call_s3(self, method, *kwarglist, **kwargs):
# -> 2117     return self.fs.call_s3(method, self.s3_additional_kwargs, *kwarglist, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\fsspec\asyn.py:121, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     118 @functools.wraps(func)
#     119 def wrapper(*args, **kwargs):
#     120     self = obj or args[0]
# --> 121     return sync(self.loop, func, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\fsspec\asyn.py:106, in sync(loop, func, timeout, *args, **kwargs)
#     104     raise FSTimeoutError from return_result
#     105 elif isinstance(return_result, BaseException):
# --> 106     raise return_result
#     107 else:
#     108     return return_result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\fsspec\asyn.py:61, in _runner(event, coro, result, timeout)
#      59     coro = asyncio.wait_for(coro, timeout=timeout)
#      60 try:
# ---> 61     result[0] = await coro
#      62 except Exception as ex:
#      63     result[0] = ex
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\s3fs\core.py:348, in S3FileSystem._call_s3(self, method, *akwarglist, **kwargs)
#     346 logger.debug("CALL: %s - %s - %s", method.__name__, akwarglist, kw2)
#     347 additional_kwargs = self._get_s3_method_kwargs(method, *akwarglist, **kwargs)
# --> 348 return await _error_wrapper(
#     349     method, kwargs=additional_kwargs, retries=self.retries
#     350 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\s3fs\core.py:140, in _error_wrapper(func, args, kwargs, retries)
#     138         err = e
#     139 err = translate_boto_error(err)
# --> 140 raise err
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\s3fs\core.py:113, in _error_wrapper(func, args, kwargs, retries)
#     111 for i in range(retries):
#     112     try:
# --> 113         return await func(*args, **kwargs)
#     114     except S3_RETRYABLE_ERRORS as e:
#     115         err = e
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\aiobotocore\client.py:361, in AioBaseClient._make_api_call(self, operation_name, api_params)
#     359 else:
#     360     apply_request_checksum(request_dict)
# --> 361     http, parsed_response = await self._make_request(
#     362         operation_model, request_dict, request_context
#     363     )
#     365 await self.meta.events.emit(
#     366     'after-call.{service_id}.{operation_name}'.format(
#     367         service_id=service_id, operation_name=operation_name
#    (...)
#     372     context=request_context,
#     373 )
#     375 if http.status_code >= 300:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\aiobotocore\client.py:386, in AioBaseClient._make_request(self, operation_model, request_dict, request_context)
#     382 async def _make_request(
#     383     self, operation_model, request_dict, request_context
#     384 ):
#     385     try:
# --> 386         return await self._endpoint.make_request(
#     387             operation_model, request_dict
#     388         )
#     389     except Exception as e:
#     390         await self.meta.events.emit(
#     391             'after-call-error.{service_id}.{operation_name}'.format(
#     392                 service_id=self._service_model.service_id.hyphenize(),
#    (...)
#     396             context=request_context,
#     397         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\aiobotocore\endpoint.py:96, in AioEndpoint._send_request(self, request_dict, operation_model)
#      94 context = request_dict['context']
#      95 self._update_retries_context(context, attempts)
# ---> 96 request = await self.create_request(request_dict, operation_model)
#      97 success_response, exception = await self._get_response(
#      98     request, operation_model, context
#      99 )
#     100 while await self._needs_retry(
#     101     attempts,
#     102     operation_model,
#    (...)
#     105     exception,
#     106 ):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\aiobotocore\endpoint.py:84, in AioEndpoint.create_request(self, params, operation_model)
#      80     service_id = operation_model.service_model.service_id.hyphenize()
#      81     event_name = 'request-created.{service_id}.{op_name}'.format(
#      82         service_id=service_id, op_name=operation_model.name
#      83     )
# ---> 84     await self._event_emitter.emit(
#      85         event_name,
#      86         request=request,
#      87         operation_name=operation_model.name,
#      88     )
#      89 prepared_request = self.prepare_request(request)
#      90 return prepared_request
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\aiobotocore\hooks.py:66, in AioHierarchicalEmitter._emit(self, event_name, kwargs, stop_on_response)
#      63 logger.debug('Event %s: calling handler %s', event_name, handler)
#      65 # Await the handler if its a coroutine.
# ---> 66 response = await resolve_awaitable(handler(**kwargs))
#      67 responses.append((handler, response))
#      68 if stop_on_response and response is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\aiobotocore\_helpers.py:15, in resolve_awaitable(obj)
#      13 async def resolve_awaitable(obj):
#      14     if inspect.isawaitable(obj):
# ---> 15         return await obj
#      17     return obj
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\aiobotocore\signers.py:24, in AioRequestSigner.handler(self, operation_name, request, **kwargs)
#      19 async def handler(self, operation_name=None, request=None, **kwargs):
#      20     # This is typically hooked up to the "request-created" event
#      21     # from a client's event emitter.  When a new request is created
#      22     # this method is invoked to sign the request.
#      23     # Don't call this method directly.
# ---> 24     return await self.sign(operation_name, request)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\aiobotocore\signers.py:82, in AioRequestSigner.sign(self, operation_name, request, region_name, signing_type, expires_in, signing_name)
#      79     else:
#      80         raise e
# ---> 82 auth.add_auth(request)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\botocore\auth.py:418, in SigV4Auth.add_auth(self, request)
#     416 def add_auth(self, request):
#     417     if self.credentials is None:
# --> 418         raise NoCredentialsError()
#     419     datetime_now = datetime.datetime.utcnow()
#     420     request.context['timestamp'] = datetime_now.strftime(SIGV4_TIMESTAMP)
#
# NoCredentialsError: Unable to locate credentials
